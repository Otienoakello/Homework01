# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("C:\\Users\\akelo\\Desktop\\DATASETS\\archive\\data.csv")

# %%
df.head()
# Out:
#   Make       Model  Year             Engine Fuel Type  Engine HP  \
# 0  BMW  1 Series M  2011  premium unleaded (required)      335.0
# 1  BMW    1 Series  2011  premium unleaded (required)      300.0
# 2  BMW    1 Series  2011  premium unleaded (required)      300.0
# 3  BMW    1 Series  2011  premium unleaded (required)      230.0
# 4  BMW    1 Series  2011  premium unleaded (required)      230.0
#
#    Engine Cylinders Transmission Type     Driven_Wheels  Number of Doors  \
# 0               6.0            MANUAL  rear wheel drive              2.0
# 1               6.0            MANUAL  rear wheel drive              2.0
# 2               6.0            MANUAL  rear wheel drive              2.0
# 3               6.0            MANUAL  rear wheel drive              2.0
# 4               6.0            MANUAL  rear wheel drive              2.0
#
#                          Market Category Vehicle Size Vehicle Style  \
# ...

# %%
df.count()
# Out:
# Make                 11914
# Model                11914
# Year                 11914
# Engine Fuel Type     11911
# Engine HP            11845
# Engine Cylinders     11884
# Transmission Type    11914
# Driven_Wheels        11914
# Number of Doors      11908
# Market Category       8172
# Vehicle Size         11914
# Vehicle Style        11914
# highway MPG          11914
# city mpg             11914
# Popularity           11914
# MSRP                 11914
# dtype: int64

# %%
df.describe()
# Out:
#                Year    Engine HP  Engine Cylinders  Number of Doors  \
# count  11914.000000  11845.00000      11884.000000     11908.000000
# mean    2010.384338    249.38607          5.628829         3.436093
# std        7.579740    109.19187          1.780559         0.881315
# min     1990.000000     55.00000          0.000000         2.000000
# 25%     2007.000000    170.00000          4.000000         2.000000
# 50%     2015.000000    227.00000          6.000000         4.000000
# 75%     2016.000000    300.00000          6.000000         4.000000
# max     2017.000000   1001.00000         16.000000         4.000000
#
#         highway MPG      city mpg    Popularity          MSRP
# count  11914.000000  11914.000000  11914.000000  1.191400e+04
# mean      26.637485     19.733255   1554.911197  4.059474e+04
# std        8.863001      8.987798   1441.855347  6.010910e+04
# min       12.000000      7.000000      2.000000  2.000000e+03
# ...

# %%
df.dtypes
# Out:
# Make                  object
# Model                 object
# Year                   int64
# Engine Fuel Type      object
# Engine HP            float64
# Engine Cylinders     float64
# Transmission Type     object
# Driven_Wheels         object
# Number of Doors      float64
# Market Category       object
# Vehicle Size          object
# Vehicle Style         object
# highway MPG            int64
# city mpg               int64
# Popularity             int64
# MSRP                   int64
# dtype: object

# %%
df.columns.str.lower().str.replace(' ','_')
# Out:
# Index(['make', 'model', 'year', 'engine_fuel_type', 'engine_hp',
#        'engine_cylinders', 'transmission_type', 'driven_wheels',
#        'number_of_doors', 'market_category', 'vehicle_size', 'vehicle_style',
#        'highway_mpg', 'city_mpg', 'popularity', 'msrp'],
#       dtype='object')

# %%
df.head(2)
# Out:
#   Make       Model  Year             Engine Fuel Type  Engine HP  \
# 0  BMW  1 Series M  2011  premium unleaded (required)      335.0
# 1  BMW    1 Series  2011  premium unleaded (required)      300.0
#
#    Engine Cylinders Transmission Type     Driven_Wheels  Number of Doors  \
# 0               6.0            MANUAL  rear wheel drive              2.0
# 1               6.0            MANUAL  rear wheel drive              2.0
#
#                          Market Category Vehicle Size Vehicle Style  \
# 0  Factory Tuner,Luxury,High-Performance      Compact         Coupe
# 1                     Luxury,Performance      Compact   Convertible
#
#    highway MPG  city mpg  Popularity   MSRP
# 0           26        19        3916  46135
# 1           28        19        3916  40650

# %%
df.columns.str.lower().str.replace(' ', '_')
# Out:
# Index(['make', 'model', 'year', 'engine_fuel_type', 'engine_hp',
#        'engine_cylinders', 'transmission_type', 'driven_wheels',
#        'number_of_doors', 'market_category', 'vehicle_size', 'vehicle_style',
#        'highway_mpg', 'city_mpg', 'popularity', 'msrp'],
#       dtype='object')

# %%
df.columns
# Out:
# Index(['Make', 'Model', 'Year', 'Engine Fuel Type', 'Engine HP',
#        'Engine Cylinders', 'Transmission Type', 'Driven_Wheels',
#        'Number of Doors', 'Market Category', 'Vehicle Size', 'Vehicle Style',
#        'highway MPG', 'city mpg', 'Popularity', 'MSRP'],
#       dtype='object')

# %%
strings = list(df.dtypes[df.dtypes == 'objects'].index)

# %%
for col in strings:
 df[col] = df[col].str.lower().str.replace(' ', '_')

# %%
df.head(n=2)
# Out:
#   Make       Model  Year             Engine Fuel Type  Engine HP  \
# 0  BMW  1 Series M  2011  premium unleaded (required)      335.0
# 1  BMW    1 Series  2011  premium unleaded (required)      300.0
#
#    Engine Cylinders Transmission Type     Driven_Wheels  Number of Doors  \
# 0               6.0            MANUAL  rear wheel drive              2.0
# 1               6.0            MANUAL  rear wheel drive              2.0
#
#                          Market Category Vehicle Size Vehicle Style  \
# 0  Factory Tuner,Luxury,High-Performance      Compact         Coupe
# 1                     Luxury,Performance      Compact   Convertible
#
#    highway MPG  city mpg  Popularity   MSRP
# 0           26        19        3916  46135
# 1           28        19        3916  40650

# %%
df['Transmission Type']
# Out:
# 0           MANUAL
# 1           MANUAL
# 2           MANUAL
# 3           MANUAL
# 4           MANUAL
#            ...
# 11909    AUTOMATIC
# 11910    AUTOMATIC
# 11911    AUTOMATIC
# 11912    AUTOMATIC
# 11913    AUTOMATIC
# Name: Transmission Type, Length: 11914, dtype: object

# %%
df.columns
# Out:
# Index(['Make', 'Model', 'Year', 'Engine Fuel Type', 'Engine HP',
#        'Engine Cylinders', 'Transmission Type', 'Driven_Wheels',
#        'Number of Doors', 'Market Category', 'Vehicle Size', 'Vehicle Style',
#        'highway MPG', 'city mpg', 'Popularity', 'MSRP'],
#       dtype='object')

# %%
df.columns.str.lower().str.replace(' ', '_',regex=True)
# Out:
# Index(['make', 'model', 'year', 'engine_fuel_type', 'engine_hp',
#        'engine_cylinders', 'transmission_type', 'driven_wheels',
#        'number_of_doors', 'market_category', 'vehicle_size', 'vehicle_style',
#        'highway_mpg', 'city_mpg', 'popularity', 'msrp'],
#       dtype='object')

# %%
df.columns
# Out:
# Index(['Make', 'Model', 'Year', 'Engine Fuel Type', 'Engine HP',
#        'Engine Cylinders', 'Transmission Type', 'Driven_Wheels',
#        'Number of Doors', 'Market Category', 'Vehicle Size', 'Vehicle Style',
#        'highway MPG', 'city mpg', 'Popularity', 'MSRP'],
#       dtype='object')

# %%
df.columns = (
    df.columns
    .str.strip() #remove leading/trailing whitespace
    .str.lower()
    .str.replace(r'\s+','_',regex=True) #replace any whitespace(space,tab,etc.)with underscore
)

# %%
df.columns
# Out:
# Index(['make', 'model', 'year', 'engine_fuel_type', 'engine_hp',
#        'engine_cylinders', 'transmission_type', 'driven_wheels',
#        'number_of_doors', 'market_category', 'vehicle_size', 'vehicle_style',
#        'highway_mpg', 'city_mpg', 'popularity', 'msrp'],
#       dtype='object')

# %%
df.head(n=2)
# Out:
#   make       model  year             engine_fuel_type  engine_hp  \
# 0  BMW  1 Series M  2011  premium unleaded (required)      335.0
# 1  BMW    1 Series  2011  premium unleaded (required)      300.0
#
#    engine_cylinders transmission_type     driven_wheels  number_of_doors  \
# 0               6.0            MANUAL  rear wheel drive              2.0
# 1               6.0            MANUAL  rear wheel drive              2.0
#
#                          market_category vehicle_size vehicle_style  \
# 0  Factory Tuner,Luxury,High-Performance      Compact         Coupe
# 1                     Luxury,Performance      Compact   Convertible
#
#    highway_mpg  city_mpg  popularity   msrp
# 0           26        19        3916  46135
# 1           28        19        3916  40650

# %%
df.dtypes
# Out:
# make                  object
# model                 object
# year                   int64
# engine_fuel_type      object
# engine_hp            float64
# engine_cylinders     float64
# transmission_type     object
# driven_wheels         object
# number_of_doors      float64
# market_category       object
# vehicle_size          object
# vehicle_style         object
# highway_mpg            int64
# city_mpg               int64
# popularity             int64
# msrp                   int64
# dtype: object

# %%
strings = list(df.dtypes[df.dtypes == 'object'].index)
strings
# Out:
# ['make',
#  'model',
#  'engine_fuel_type',
#  'transmission_type',
#  'driven_wheels',
#  'market_category',
#  'vehicle_size',
#  'vehicle_style']

# %%
for col in strings:
    df[col] = df[col].str.strip().str.lower().str.replace(r'\s+','_',regex=True)

# %%
df.head()
# Out:
#   make       model  year             engine_fuel_type  engine_hp  \
# 0  bmw  1_series_m  2011  premium_unleaded_(required)      335.0
# 1  bmw    1_series  2011  premium_unleaded_(required)      300.0
# 2  bmw    1_series  2011  premium_unleaded_(required)      300.0
# 3  bmw    1_series  2011  premium_unleaded_(required)      230.0
# 4  bmw    1_series  2011  premium_unleaded_(required)      230.0
#
#    engine_cylinders transmission_type     driven_wheels  number_of_doors  \
# 0               6.0            manual  rear_wheel_drive              2.0
# 1               6.0            manual  rear_wheel_drive              2.0
# 2               6.0            manual  rear_wheel_drive              2.0
# 3               6.0            manual  rear_wheel_drive              2.0
# 4               6.0            manual  rear_wheel_drive              2.0
#
#                          market_category vehicle_size vehicle_style  \
# ...

# %%
df.dtypes
# Out:
# make                  object
# model                 object
# year                   int64
# engine_fuel_type      object
# engine_hp            float64
# engine_cylinders     float64
# transmission_type     object
# driven_wheels         object
# number_of_doors      float64
# market_category       object
# vehicle_size          object
# vehicle_style         object
# highway_mpg            int64
# city_mpg               int64
# popularity             int64
# msrp                   int64
# dtype: object

# %%
for col in df.columns:
    print(col)
    print(df[col].unique()[:5])
    print(df[col].nunique())
    print()
# Out:
# make
# ['bmw' 'audi' 'fiat' 'mercedes-benz' 'chrysler']
# 48
#
# model
# ['1_series_m' '1_series' '100' '124_spider' '190-class']
# 914
#
# year
# [2011 2012 2013 1992 1993]
# 28
#
# engine_fuel_type
# ['premium_unleaded_(required)' 'regular_unleaded'
#  'premium_unleaded_(recommended)' 'flex-fuel_(unleaded/e85)' 'diesel']
# 10
#
# engine_hp
# [335. 300. 230. 320. 172.]
# 356
#
# engine_cylinders
# [ 6.  4.  5.  8. 12.]
# 9
#
# transmission_type
# ['manual' 'automatic' 'automated_manual' 'direct_drive' 'unknown']
# 5
#
# driven_wheels
# ['rear_wheel_drive' 'front_wheel_drive' 'all_wheel_drive'
#  'four_wheel_drive']
# 4
#
# number_of_doors
# [ 2.  4.  3. nan]
# 3
#
# market_category
# ['factory_tuner,luxury,high-performance' 'luxury,performance'
#  'luxury,high-performance' 'luxury' 'performance']
# 71
#
# vehicle_size
# ['compact' 'midsize' 'large']
# 3
#
# vehicle_style
# ['coupe' 'convertible' 'sedan' 'wagon' '4dr_hatchback']
# 16
#
# highway_mpg
# [26 28 27 25 24]
# 59
#
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# %matplotlib inline

# %%
sns.histplot(df.msrp[df.msrp < 100000], bins = 50)
# Out:
# <Axes: xlabel='msrp', ylabel='Count'>

# %%
np.log([1,10,1000,100000])
# Out:
# array([ 0.        ,  2.30258509,  6.90775528, 11.51292546])

# %%
np.log1p([0,10,100,1000,10000,100000])
# Out:
# array([ 0.        ,  2.39789527,  4.61512052,  6.90875478,  9.21044037,
#        11.51293546])

# %%
prices_logs = np.log1p(df.msrp)

# %%
prices_logs
# Out:
# 0        10.739349
# 1        10.612779
# 2        10.500977
# 3        10.290483
# 4        10.448744
#            ...
# 11909    10.739024
# 11910    10.945018
# 11911    10.832122
# 11912    10.838031
# 11913    10.274913
# Name: msrp, Length: 11914, dtype: float64

# %%
sns.histplot(prices_logs, bins = 100)
# Out:
# <Axes: xlabel='msrp', ylabel='Count'>

# %%
df.isnull().sum()
# Out:
# make                    0
# model                   0
# year                    0
# engine_fuel_type        3
# engine_hp              69
# engine_cylinders       30
# transmission_type       0
# driven_wheels           0
# number_of_doors         6
# market_category      3742
# vehicle_size            0
# vehicle_style           0
# highway_mpg             0
# city_mpg                0
# popularity              0
# msrp                    0
# dtype: int64

# %%
len(df)
# Out:
# 11914

# %%
n = len(df)
n_val = int(n*0.2)
n_test = int(n*0.2)
n_train = n- n_val - n_test

# %%
n_val, n_test, n_train
# Out:
# (2382, 2382, 7150)

# %%
total = n_val + n_test + n_train

# %%
total
# Out:
# 11914

# %%
df_train = df.iloc[:n_train]
df_val = df.iloc[n_train:n_train + n_val]
df_test = df.iloc[n_train + n_val:]

# %%
df_train
# Out:
#          make       model  year             engine_fuel_type  engine_hp  \
# 0         bmw  1_series_m  2011  premium_unleaded_(required)      335.0
# 1         bmw    1_series  2011  premium_unleaded_(required)      300.0
# 2         bmw    1_series  2011  premium_unleaded_(required)      300.0
# 3         bmw    1_series  2011  premium_unleaded_(required)      230.0
# 4         bmw    1_series  2011  premium_unleaded_(required)      230.0
# ...       ...         ...   ...                          ...        ...
# 7145    mazda      navajo  1994             regular_unleaded      160.0
# 7146    mazda      navajo  1994             regular_unleaded      160.0
# 7147  lincoln   navigator  2015             regular_unleaded      365.0
# 7148  lincoln   navigator  2015             regular_unleaded      365.0
# 7149  lincoln   navigator  2015             regular_unleaded      365.0
#
#       engine_cylinders transmission_type     driven_wheels  number_of_doors  \
# ...

# %%
idx= np.arange(n)

# %%
np.random.seed(2)
np.random.shuffle(idx)

# %%
idx
# Out:
# array([2735, 6720, 5878, ..., 6637, 2575, 7336], shape=(11914,))

# %%
df_train = df.iloc[idx[:n_train]]
df_val = df.iloc[idx[n_train:n_train + n_val]]
df_test = df.iloc[idx[n_train + n_val:]]

# %%
df_test
# Out:
#                 make           model  year          engine_fuel_type  \
# 11195            gmc         vandura  1994          regular_unleaded
# 673    mercedes-benz       600-class  1993          regular_unleaded
# 11270         toyota           venza  2013          regular_unleaded
# 752            volvo             740  1992          regular_unleaded
# 3137            ford  crown_victoria  2010  flex-fuel_(unleaded/e85)
# ...              ...             ...   ...                       ...
# 2514       chevrolet       chevy_van  1998          regular_unleaded
# 11798         subaru    xv_crosstrek  2014          regular_unleaded
# 6637           dodge          magnum  2006          regular_unleaded
# 2575           honda           civic  2016          regular_unleaded
# 7336          subaru         outback  2015          regular_unleaded
#
#        engine_hp  engine_cylinders transmission_type      driven_wheels  \
# ...

# %%
df_val
# Out:
#                 make                    model  year  \
# 2779       chevrolet                 colorado  2015
# 3708   mercedes-benz                  e-class  2017
# 4794            ford                    focus  2017
# 10498          acura                      tlx  2016
# 1880      volkswagen       beetle_convertible  2016
# ...              ...                      ...   ...
# 11123          volvo                      v60  2015
# 5549        maserati  granturismo_convertible  2015
# 4146        cadillac          escalade_hybrid  2013
# 6337      mitsubishi                   lancer  2016
# 9814             kia                  sorento  2015
#
#                      engine_fuel_type  engine_hp  engine_cylinders  \
# 2779                 regular_unleaded      200.0               4.0
# 3708      premium_unleaded_(required)      241.0               4.0
# 4794         flex-fuel_(unleaded/e85)      160.0               4.0
# ...

# %%
df_train
# Out:
#               make        model  year                engine_fuel_type  \
# 2735     chevrolet       cobalt  2008                regular_unleaded
# 6720        toyota       matrix  2012                regular_unleaded
# 5878        subaru      impreza  2016                regular_unleaded
# 11190   volkswagen      vanagon  1991                regular_unleaded
# 4554          ford        f-150  2017        flex-fuel_(unleaded/e85)
# ...            ...          ...   ...                             ...
# 434            bmw     4_series  2015     premium_unleaded_(required)
# 1902    volkswagen       beetle  2015  premium_unleaded_(recommended)
# 9334           gmc  sierra_1500  2015        flex-fuel_(unleaded/e85)
# 5284   rolls-royce        ghost  2014     premium_unleaded_(required)
# 2420    volkswagen           cc  2017  premium_unleaded_(recommended)
#
#        engine_hp  engine_cylinders transmission_type      driven_wheels  \
# ...

# %%
df.head()
# Out:
#   make       model  year             engine_fuel_type  engine_hp  \
# 0  bmw  1_series_m  2011  premium_unleaded_(required)      335.0
# 1  bmw    1_series  2011  premium_unleaded_(required)      300.0
# 2  bmw    1_series  2011  premium_unleaded_(required)      300.0
# 3  bmw    1_series  2011  premium_unleaded_(required)      230.0
# 4  bmw    1_series  2011  premium_unleaded_(required)      230.0
#
#    engine_cylinders transmission_type     driven_wheels  number_of_doors  \
# 0               6.0            manual  rear_wheel_drive              2.0
# 1               6.0            manual  rear_wheel_drive              2.0
# 2               6.0            manual  rear_wheel_drive              2.0
# 3               6.0            manual  rear_wheel_drive              2.0
# 4               6.0            manual  rear_wheel_drive              2.0
#
#                          market_category vehicle_size vehicle_style  \
# ...

# %%
df_train.head()
# Out:
#              make    model  year          engine_fuel_type  engine_hp  \
# 2735    chevrolet   cobalt  2008          regular_unleaded      148.0
# 6720       toyota   matrix  2012          regular_unleaded      132.0
# 5878       subaru  impreza  2016          regular_unleaded      148.0
# 11190  volkswagen  vanagon  1991          regular_unleaded       90.0
# 4554         ford    f-150  2017  flex-fuel_(unleaded/e85)      385.0
#
#        engine_cylinders transmission_type      driven_wheels  number_of_doors  \
# 2735                4.0            manual  front_wheel_drive              2.0
# 6720                4.0         automatic  front_wheel_drive              4.0
# 5878                4.0         automatic    all_wheel_drive              4.0
# 11190               4.0            manual   rear_wheel_drive              3.0
# 4554                8.0         automatic   four_wheel_drive              4.0
#
# ...

# %%
df_train.head(10)
# Out:
#              make            model  year             engine_fuel_type  \
# 2735    chevrolet           cobalt  2008             regular_unleaded
# 6720       toyota           matrix  2012             regular_unleaded
# 5878       subaru          impreza  2016             regular_unleaded
# 11190  volkswagen          vanagon  1991             regular_unleaded
# 4554         ford            f-150  2017     flex-fuel_(unleaded/e85)
# 8001   volkswagen           rabbit  2008             regular_unleaded
# 2882      bentley  continental_gtc  2013  premium_unleaded_(required)
# 649           bmw         6_series  2015  premium_unleaded_(required)
# 616       maybach               57  2012  premium_unleaded_(required)
# 4459         ford   f-150_heritage  2004             regular_unleaded
#
#        engine_hp  engine_cylinders transmission_type      driven_wheels  \
# 2735       148.0               4.0            manual  front_wheel_drive
# ...

# %%
len(df_train),len(df_val),len(df_test)
# Out:
# (7150, 2382, 2382)

# %%
df_train = df_train.reset_index(drop = True)
df_val = df_val.reset_index(drop = True)
df_test = df_test.reset_index(drop = True)

# %%
df_train
# Out:
#              make        model  year                engine_fuel_type  \
# 0       chevrolet       cobalt  2008                regular_unleaded
# 1          toyota       matrix  2012                regular_unleaded
# 2          subaru      impreza  2016                regular_unleaded
# 3      volkswagen      vanagon  1991                regular_unleaded
# 4            ford        f-150  2017        flex-fuel_(unleaded/e85)
# ...           ...          ...   ...                             ...
# 7145          bmw     4_series  2015     premium_unleaded_(required)
# 7146   volkswagen       beetle  2015  premium_unleaded_(recommended)
# 7147          gmc  sierra_1500  2015        flex-fuel_(unleaded/e85)
# 7148  rolls-royce        ghost  2014     premium_unleaded_(required)
# 7149   volkswagen           cc  2017  premium_unleaded_(recommended)
#
#       engine_hp  engine_cylinders transmission_type      driven_wheels  \
# ...

# %%
df_train.head(10)
# Out:
#          make            model  year             engine_fuel_type  engine_hp  \
# 0   chevrolet           cobalt  2008             regular_unleaded      148.0
# 1      toyota           matrix  2012             regular_unleaded      132.0
# 2      subaru          impreza  2016             regular_unleaded      148.0
# 3  volkswagen          vanagon  1991             regular_unleaded       90.0
# 4        ford            f-150  2017     flex-fuel_(unleaded/e85)      385.0
# 5  volkswagen           rabbit  2008             regular_unleaded      170.0
# 6     bentley  continental_gtc  2013  premium_unleaded_(required)      500.0
# 7         bmw         6_series  2015  premium_unleaded_(required)      315.0
# 8     maybach               57  2012  premium_unleaded_(required)      543.0
# 9        ford   f-150_heritage  2004             regular_unleaded      202.0
#
#    engine_cylinders transmission_type      driven_wheels  number_of_doors  \
# ...

# %%
df_val.head(10)
# Out:
#             make               model  year                engine_fuel_type  \
# 0      chevrolet            colorado  2015                regular_unleaded
# 1  mercedes-benz             e-class  2017     premium_unleaded_(required)
# 2           ford               focus  2017        flex-fuel_(unleaded/e85)
# 3          acura                 tlx  2016  premium_unleaded_(recommended)
# 4     volkswagen  beetle_convertible  2016                regular_unleaded
# 5         toyota              pickup  1995                regular_unleaded
# 6         nissan              murano  2016                regular_unleaded
# 7           saab                 900  1996                regular_unleaded
# 8     land_rover          freelander  2004                regular_unleaded
# 9          dodge             stratus  2004                regular_unleaded
#
#    engine_hp  engine_cylinders transmission_type      driven_wheels  \
# 0      200.0               4.0         automatic   four_wheel_drive
# ...

# %%
df_train.msrp
# Out:
# 0        14410
# 1        19685
# 2        19795
# 3         2000
# 4        56260
#          ...
# 7145     54900
# 7146     29215
# 7147     34675
# 7148    303300
# 7149     37820
# Name: msrp, Length: 7150, dtype: int64

# %%
y_train = np.log1p(df_train.msrp.values)
y_val = np.log1p(df_val.msrp.values)   
y_test = np.log1p(df_test.msrp.values)

# %%
y_test
# Out:
# array([ 7.60140233,  8.07464908, 10.34563811, ..., 10.27852782,
#        10.00789261, 10.40414162], shape=(2382,))

# %%
del df_train['msrp']
del df_val['msrp']
del df_test['msrp']

# %%
len(y_train)
# Out:
# 7150

# %%
len(y_test)
# Out:
# 2382

# %%
len(y_val)
# Out:
# 2382

# %%
df.head(10)
# Out:
#   make       model  year             engine_fuel_type  engine_hp  \
# 0  bmw  1_series_m  2011  premium_unleaded_(required)      335.0
# 1  bmw    1_series  2011  premium_unleaded_(required)      300.0
# 2  bmw    1_series  2011  premium_unleaded_(required)      300.0
# 3  bmw    1_series  2011  premium_unleaded_(required)      230.0
# 4  bmw    1_series  2011  premium_unleaded_(required)      230.0
# 5  bmw    1_series  2012  premium_unleaded_(required)      230.0
# 6  bmw    1_series  2012  premium_unleaded_(required)      300.0
# 7  bmw    1_series  2012  premium_unleaded_(required)      300.0
# 8  bmw    1_series  2012  premium_unleaded_(required)      230.0
# 9  bmw    1_series  2013  premium_unleaded_(required)      230.0
#
#    engine_cylinders transmission_type     driven_wheels  number_of_doors  \
# 0               6.0            manual  rear_wheel_drive              2.0
# 1               6.0            manual  rear_wheel_drive              2.0
# ...

# %%
df_train
# Out:
#              make        model  year                engine_fuel_type  \
# 0       chevrolet       cobalt  2008                regular_unleaded
# 1          toyota       matrix  2012                regular_unleaded
# 2          subaru      impreza  2016                regular_unleaded
# 3      volkswagen      vanagon  1991                regular_unleaded
# 4            ford        f-150  2017        flex-fuel_(unleaded/e85)
# ...           ...          ...   ...                             ...
# 7145          bmw     4_series  2015     premium_unleaded_(required)
# 7146   volkswagen       beetle  2015  premium_unleaded_(recommended)
# 7147          gmc  sierra_1500  2015        flex-fuel_(unleaded/e85)
# 7148  rolls-royce        ghost  2014     premium_unleaded_(required)
# 7149   volkswagen           cc  2017  premium_unleaded_(recommended)
#
#       engine_hp  engine_cylinders transmission_type      driven_wheels  \
# ...

# %%
df_train.iloc[10]
# Out:
# make                                 rolls-royce
# model                     phantom_drophead_coupe
# year                                        2015
# engine_fuel_type     premium_unleaded_(required)
# engine_hp                                  453.0
# engine_cylinders                            12.0
# transmission_type                      automatic
# driven_wheels                   rear_wheel_drive
# number_of_doors                              2.0
# market_category        exotic,luxury,performance
# vehicle_size                               large
# vehicle_style                        convertible
# highway_mpg                                   19
# city_mpg                                      11
# popularity                                    86
# Name: 10, dtype: object

# %%
xi = [453,11,86]

# %%
def g(xi):
 #do something
 return 10000

# %%
g(xi)
# Out:
# 10000

# %%
w0 = 7.17
w = [0.01,0.04,0.002]

# %%
def linear_regression(xi):
 n=len(xi)
 pred = w0
 for j in range(n):
  pred = pred + w[j]*xi[j]

 return pred

# %%
linear_regression(xi)
# Out:
# 12.312

# %%
np.expm1(linear_regression(xi))
# Out:
# np.float64(222347.2221101062)

# %%
def dot(xi,w):
 n =len(xi)

 res =0.0
 for j in range(n):
     res = res + xi [j] * w[j]
 return res

# %%
w_new = [w0] + w

# %%
w_new
# Out:
# [7.17, 0.01, 0.04, 0.002]

# %%
def linear_regression(xi):
    xi = [1] + xi
    return dot(xi, w_new)

# %%
linear_regression(xi)
# Out:
# 12.312

# %%
np.exp(12.312)
# Out:
# np.float64(222348.2221101062)

# %%
xi = [453, 11, 86]
w0 = 7.17
w_new = [w0] + w

# %%
x1 = [1, 148, 24, 1385]
x2 = [1, 132, 25, 2031]
x10 = [1, 453, 11, 86]

# %%
x = [x1, x2, x10]
x = np.array(x)
x
# Out:
# array([[   1,  148,   24, 1385],
#        [   1,  132,   25, 2031],
#        [   1,  453,   11,   86]])

# %%
x.dot(w_new)
# Out:
# array([12.38 , 13.552, 12.312])

# %%
def linear_regression(x):
 return x.dot(w_new)

# %%
linear_regression(x)
# Out:
# array([12.38 , 13.552, 12.312])

# %%
def train_linear_regression(x,y):
 pass

# %%
x = [
    [148,24,1385],
    [132,25,2031],
    [453,11,86],
    [158,24,185],
    [172,25,201],
    [413,11,86],
    [38,54,185],
    [142,25,431],
    [453,31,86],
]

# %%
x = np.array(x)

# %%
x
# Out:
# array([[ 148,   24, 1385],
#        [ 132,   25, 2031],
#        [ 453,   11,   86],
#        [ 158,   24,  185],
#        [ 172,   25,  201],
#        [ 413,   11,   86],
#        [  38,   54,  185],
#        [ 142,   25,  431],
#        [ 453,   31,   86]])

# %%
ones = np.ones(x.shape[0])
ones
# Out:
# array([1., 1., 1., 1., 1., 1., 1., 1., 1.])

# %%
x = np.column_stack([ones,x])

# %%
y = [100, 200, 150, 250, 100, 200, 150, 250, 120]

# %%
XTX = x.T.dot(x)

# %%
XTX_inv = np.linalg.inv(XTX)

# %%
w_full = XTX_inv.dot(x.T).dot(y)

# %%
w0 = w_full[0]
w = w_full[1:]

# %%
w0,w
# Out:
# (np.float64(300.0677669255554), array([-0.22774253, -2.5769413 , -0.02301206]))

# %%
#def train_linear_regression(x,y):
 #   ones = np.ones(x.shape[0])
  #  x = np.column_stack([ones,x])

   # XTX = x.T.dot(x)
    #XTX_inv = np.linalg.inv(XTX)
   # w_full = XTX_inv.dot(x.T).dot(y)

    #return w_full[0],w_full[1:]/*

# %%
train_linear_regression(x, y)

# %%
def train_linear_regression(x, y):
    ones = np.ones(x.shape[0])
    x = np.column_stack([ones, x])
    #I am replacing it with pseudoinverse
    w_full = np.linalg.pinv(x).dot(y)
    return w_full[0], w_full[1:]

# %%
train_linear_regression(x, y)
# Out:
# (np.float64(150.03388346275773),
#  array([ 1.50033883e+02, -2.27742529e-01, -2.57694130e+00, -2.30120640e-02]))

# %%
df_train
# Out:
#              make        model  year                engine_fuel_type  \
# 0       chevrolet       cobalt  2008                regular_unleaded
# 1          toyota       matrix  2012                regular_unleaded
# 2          subaru      impreza  2016                regular_unleaded
# 3      volkswagen      vanagon  1991                regular_unleaded
# 4            ford        f-150  2017        flex-fuel_(unleaded/e85)
# ...           ...          ...   ...                             ...
# 7145          bmw     4_series  2015     premium_unleaded_(required)
# 7146   volkswagen       beetle  2015  premium_unleaded_(recommended)
# 7147          gmc  sierra_1500  2015        flex-fuel_(unleaded/e85)
# 7148  rolls-royce        ghost  2014     premium_unleaded_(required)
# 7149   volkswagen           cc  2017  premium_unleaded_(recommended)
#
#       engine_hp  engine_cylinders transmission_type      driven_wheels  \
# ...

# %%
df_train.dtypes
# Out:
# make                  object
# model                 object
# year                   int64
# engine_fuel_type      object
# engine_hp            float64
# engine_cylinders     float64
# transmission_type     object
# driven_wheels         object
# number_of_doors      float64
# market_category       object
# vehicle_size          object
# vehicle_style         object
# highway_mpg            int64
# city_mpg               int64
# popularity             int64
# dtype: object

# %%
df_train.columns
# Out:
# Index(['make', 'model', 'year', 'engine_fuel_type', 'engine_hp',
#        'engine_cylinders', 'transmission_type', 'driven_wheels',
#        'number_of_doors', 'market_category', 'vehicle_size', 'vehicle_style',
#        'highway_mpg', 'city_mpg', 'popularity'],
#       dtype='object')

# %%
base = ['engine_hp','engine_cylinders', 'highway_mpg', 'city_mpg', 'popularity']

# %%
df_train[base]
# Out:
#       engine_hp  engine_cylinders  highway_mpg  city_mpg  popularity
# 0         148.0               4.0           33        24        1385
# 1         132.0               4.0           32        25        2031
# 2         148.0               4.0           37        28         640
# 3          90.0               4.0           18        16         873
# 4         385.0               8.0           21        15        5657
# ...         ...               ...          ...       ...         ...
# 7145      300.0               6.0           31        20        3916
# 7146      210.0               4.0           30        24         873
# 7147      285.0               6.0           22        17         549
# 7148      563.0              12.0           21        13          86
# 7149      200.0               4.0           31        22         873
#
# [7150 rows x 5 columns]

# %%
x_train = df_train[base].values

# %%
df_train[base].isnull().sum()
# Out:
# engine_hp           40
# engine_cylinders    14
# highway_mpg          0
# city_mpg             0
# popularity           0
# dtype: int64

# %%
df_train[base].fillna(0).isnull().sum()
# Out:
# engine_hp           0
# engine_cylinders    0
# highway_mpg         0
# city_mpg            0
# popularity          0
# dtype: int64

# %%
x_train = df_train[base].fillna(0).values

# %%
train_linear_regression(x_train,y_train)
# Out:
# (np.float64(7.927257388070033),
#  array([ 9.70589522e-03, -1.59103494e-01,  1.43792133e-02,  1.49441072e-02,
#         -9.06908672e-06]))

# %%
w0,w = train_linear_regression(x_train,y_train)

# %%
y_pred = w0 + x_train.dot(w)

# %%
sns.histplot(y_pred, color ='red', alpha = 0.5, bins = 50)
sns.histplot(y_train, color ='blue', alpha = 0.5, bins = 50)
# Out:
# <Axes: ylabel='Count'>

# %%
def rmse(y,y_train):
    error = y-y_pred
    se = (error)**2
    mse =se.mean()
    return np.sqrt(mse)

# %%
rmse(y_train,y_pred)
# Out:
# np.float64(0.7554192603920132)

# %%
x_train = df_train[base].values
x_train = df_train[base].fillna(0).values
w0,w = train_linear_regression(x_train,y_train)
y_pred = w0 + x_train.dot(w)

# %%
def prepare_x(df):
   df_num = df[base]
   df_num = df_num.fillna(0)
   x = df_num.values
   return x

# %%
x_train = prepare_x(df_train)
w0,w = train_linear_regression(x_train,y_train)

x_val = prepare_x(df_val)
y_pred = w0 + x_val.dot(w)

rmse(y_val,y_pred)
# Out:
# np.float64(0.7616530991301582)

# %%
df_train.year.max()
# Out:
# np.int64(2017)

# %%
2017-df_train.year
# Out:
# 0        9
# 1        5
# 2        1
# 3       26
# 4        0
#         ..
# 7145     2
# 7146     2
# 7147     2
# 7148     3
# 7149     0
# Name: year, Length: 7150, dtype: int64

# %%
#def prepare_x(df):
# df = df.copy()  
# df['age'] = 2017-df.year
# features = base + ['age']
 #df_num =df['features']
 #df_num =df_num.fillna(0)
# x = df_num.values
# return x

# %%
def prepare_x(df):
    df = df.copy()  
    df['age'] = 2017 - df.year
    features = base + ['age']
    df_num = df[features]  # Corrected line
    df_num = df_num.fillna(0)
    x = df_num.values
    return x

# %%
x_train = prepare_x(df_train)

# %%
df_train.dtypes
# Out:
# make                  object
# model                 object
# year                   int64
# engine_fuel_type      object
# engine_hp            float64
# engine_cylinders     float64
# transmission_type     object
# driven_wheels         object
# number_of_doors      float64
# market_category       object
# vehicle_size          object
# vehicle_style         object
# highway_mpg            int64
# city_mpg               int64
# popularity             int64
# dtype: object

# %%
df_train.dtypes
# Out:
# make                  object
# model                 object
# year                   int64
# engine_fuel_type      object
# engine_hp            float64
# engine_cylinders     float64
# transmission_type     object
# driven_wheels         object
# number_of_doors      float64
# market_category       object
# vehicle_size          object
# vehicle_style         object
# highway_mpg            int64
# city_mpg               int64
# popularity             int64
# dtype: object

# %%
x_train
# Out:
# array([[1.480e+02, 4.000e+00, 3.300e+01, 2.400e+01, 1.385e+03, 9.000e+00],
#        [1.320e+02, 4.000e+00, 3.200e+01, 2.500e+01, 2.031e+03, 5.000e+00],
#        [1.480e+02, 4.000e+00, 3.700e+01, 2.800e+01, 6.400e+02, 1.000e+00],
#        ...,
#        [2.850e+02, 6.000e+00, 2.200e+01, 1.700e+01, 5.490e+02, 2.000e+00],
#        [5.630e+02, 1.200e+01, 2.100e+01, 1.300e+01, 8.600e+01, 3.000e+00],
#        [2.000e+02, 4.000e+00, 3.100e+01, 2.200e+01, 8.730e+02, 0.000e+00]],
#       shape=(7150, 6))

# %%
x_train = prepare_x(df_train)
w0,w = train_linear_regression(x_train,y_train)

x_val = prepare_x(df_val)
y_pred = w0 + x_val.dot(w)

rmse(y_val,y_pred)
# Out:
# np.float64(0.5172055461058341)

# %%
sns.histplot(y_pred, color ='red', alpha = 0.5, bins = 50)
sns.histplot(y_val, color ='blue', alpha = 0.5, bins = 50)
# Out:
# <Axes: ylabel='Count'>

# %%
df_train.number_of_doors.nunique()
# Out:
# 3

# %%
df_train.number_of_doors.unique()[:3]
# Out:
# array([2., 4., 3.])

# %%
df_train['num_of_doors_2'] = (df_train.number_of_doors == 2).astype('int')
df_train['num_of_doors_3'] = (df_train.number_of_doors == 3).astype('int')
df_train['num_of_doors_4'] = (df_train.number_of_doors == 4).astype('int')

# %%
df_train
# Out:
#              make        model  year                engine_fuel_type  \
# 0       chevrolet       cobalt  2008                regular_unleaded
# 1          toyota       matrix  2012                regular_unleaded
# 2          subaru      impreza  2016                regular_unleaded
# 3      volkswagen      vanagon  1991                regular_unleaded
# 4            ford        f-150  2017        flex-fuel_(unleaded/e85)
# ...           ...          ...   ...                             ...
# 7145          bmw     4_series  2015     premium_unleaded_(required)
# 7146   volkswagen       beetle  2015  premium_unleaded_(recommended)
# 7147          gmc  sierra_1500  2015        flex-fuel_(unleaded/e85)
# 7148  rolls-royce        ghost  2014     premium_unleaded_(required)
# 7149   volkswagen           cc  2017  premium_unleaded_(recommended)
#
#       engine_hp  engine_cylinders transmission_type      driven_wheels  \
# ...

# %%
def prepare_x(df):
    df = df.copy()
    features = base.copy()
    df['age'] = 2017 - df.year
    features.append('age')

    for v in [2, 3, 4]:
        df['num_doors_%s' % v] = (df.number_of_doors == v).astype('int')
        features.append('num_doors_%s' % v)

    df_num = df[features]  # Corrected line
    df_num = df_num.fillna(0)
    x = df_num.values
    return x

# %%
prepare_x(df_train)
# Out:
# array([[148.,   4.,  33., ...,   1.,   0.,   0.],
#        [132.,   4.,  32., ...,   0.,   0.,   1.],
#        [148.,   4.,  37., ...,   0.,   0.,   1.],
#        ...,
#        [285.,   6.,  22., ...,   0.,   0.,   1.],
#        [563.,  12.,  21., ...,   0.,   0.,   1.],
#        [200.,   4.,  31., ...,   0.,   0.,   1.]], shape=(7150, 9))

# %%
x_train = prepare_x(df_train)
w0,w = train_linear_regression(x_train,y_train)

x_val = prepare_x(df_val)
y_pred = w0 + x_val.dot(w)

rmse(y_val,y_pred)
# Out:
# np.float64(0.5157995641502447)

# %%
makes = list(df.make.value_counts().head().index)
makes
# Out:
# ['chevrolet', 'ford', 'volkswagen', 'toyota', 'dodge']

# %%
def prepare_x(df):
    df = df.copy()
    features = base.copy()
    df['age'] = 2017 - df.year
    features.append('age')

    for v in [2, 3, 4]:
        df['num_doors_%s' % v] = (df.number_of_doors == v).astype('int')
        features.append('num_doors_%s' % v)

    for v in makes:
        df['make_%s' % v] = (df.make == v).astype('int')
        features.append('make_%s' % v)

    df_num = df[features]  # Corrected line
    df_num = df_num.fillna(0)
    x = df_num.values
    return x

# %%
x_train = prepare_x(df_train)
w0,w = train_linear_regression(x_train,y_train)

x_val = prepare_x(df_val)
y_pred = w0 + x_val.dot(w)

rmse(y_val,y_pred)
# Out:
# np.float64(0.5076038849557346)

# %%
df.dtypes
# Out:
# make                  object
# model                 object
# year                   int64
# engine_fuel_type      object
# engine_hp            float64
# engine_cylinders     float64
# transmission_type     object
# driven_wheels         object
# number_of_doors      float64
# market_category       object
# vehicle_size          object
# vehicle_style         object
# highway_mpg            int64
# city_mpg               int64
# popularity             int64
# msrp                   int64
# dtype: object

# %%
df.columns = df.columns.str.strip()

# %%
categorical_variables = [
    'make',
    'engine_fuel_type',
    'transmission_type',
    'driven_wheels',
    'market_category',
    'vehicle_size',
    'vehicle_style'
]

# %%
categories = {}
for c in categorical_variables:
    categories[c] = list(df[c].value_counts().head().index)

# %%
categories
# Out:
# {'make': ['chevrolet', 'ford', 'volkswagen', 'toyota', 'dodge'],
#  'engine_fuel_type': ['regular_unleaded',
#   'premium_unleaded_(required)',
#   'premium_unleaded_(recommended)',
#   'flex-fuel_(unleaded/e85)',
#   'diesel'],
#  'transmission_type': ['automatic',
#   'manual',
#   'automated_manual',
#   'direct_drive',
#   'unknown'],
#  'driven_wheels': ['front_wheel_drive',
#   'rear_wheel_drive',
#   'all_wheel_drive',
#   'four_wheel_drive'],
#  'market_category': ['crossover',
#   'flex_fuel',
#   'luxury',
#   'luxury,performance',
#   'hatchback'],
#  'vehicle_size': ['compact', 'midsize', 'large'],
#  'vehicle_style': ['sedan',
#   '4dr_suv',
#   'coupe',
#   'convertible',
#   '4dr_hatchback']}

# %%
def prepare_x(df):
    df = df.copy()
    features = base.copy()
    df['age'] = 2017 - df.year
    features.append('age')

    for v in [2, 3, 4]:
        df['num_doors_%s' % v] = (df.number_of_doors == v).astype('int')
        features.append('num_doors_%s' % v)

    for c, values in categories.items():
        for v in values:
         df['%s_%s' % (c,v)] = (df[c] == v).astype('int')
         features.append('%s_%s'%(c,v))

    df_num = df[features]  # Corrected line
    df_num = df_num.fillna(0)
    x = df_num.values
    return x

# %%
x_train = prepare_x(df_train)
w0,w = train_linear_regression(x_train,y_train)

x_val = prepare_x(df_val)
y_pred = w0 + x_val.dot(w)

rmse(y_val,y_pred)
# Out:
# np.float64(0.45651701369455455)

# %%
sns.histplot(y_pred, color ='red', alpha = 0.5, bins = 50)
sns.histplot(y_val, color ='blue', alpha = 0.5, bins = 50)
# Out:
# <Axes: ylabel='Count'>

# %%
w0
# Out:
# np.float64(6.286648809087835)

# %%
int(w0)
# Out:
# 6

# %%
w
# Out:
# array([ 1.74593372e-03,  1.10325823e-01, -5.11418923e-03, -5.92586749e-03,
#        -5.03742753e-05, -9.62111445e-02, -7.90258141e-01, -8.94737411e-01,
#        -6.21770069e-01, -4.23848964e-02,  1.77113119e-01,  1.38350936e-02,
#        -9.97691067e-02, -1.07727665e-01, -4.61172642e-01,  6.90591028e-02,
#        -3.27355835e-01, -5.40202560e-01, -9.20899158e-02,  1.09415308e+00,
#         9.24610461e-01,  1.15493509e+00,  2.62188423e+00,  4.91065955e-01,
#         1.60772043e+00,  1.53754458e+00,  1.60068184e+00,  1.54070197e+00,
#        -8.49948610e-02,  4.57050445e-02, -4.80495451e-02, -3.56610936e-02,
#         8.60297486e-03,  2.18093536e+00,  2.06578234e+00,  2.03993110e+00,
#        -4.85492239e-02,  5.44797374e-02,  1.78241160e-01,  3.41906701e-01,
#        -1.64412078e-01])

# %%
X =[[4,4,4],
    [3,5,5],
    [5,1,1],
    [5,4,4],
    [7,5,5],
    [4,5,5.00000001]]
X = np.array(X)

# %%
X
# Out:
# array([[4.        , 4.        , 4.        ],
#        [3.        , 5.        , 5.        ],
#        [5.        , 1.        , 1.        ],
#        [5.        , 4.        , 4.        ],
#        [7.        , 5.        , 5.        ],
#        [4.        , 5.        , 5.00000001]])

# %%
XTX = X.T.dot(X)
XTX
# Out:
# array([[140.        , 111.        , 111.00000004],
#        [111.        , 108.        , 108.00000005],
#        [111.00000004, 108.00000005, 108.0000001 ]])

# %%
XTX_inv = np.linalg.pinv(XTX)

# %%
XTX_inv.dot(X.T).dot(y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[156], line 1
# ----> 1 XTX_inv.dot(X.T).dot(y)
#
# ValueError: shapes (3,6) and (9,) not aligned: 6 (dim 1) != 9 (dim 0)

# %%
XTX = XTX + 0.01*np.eye(3)

# %%
XTX_inv = np.linalg.pinv(XTX)
XTX_inv

# %%
XTX_inv.dot(X.T)

# %%
def train_linear_regression_reg(x,y,r=0.001):
    ones =np.ones(x.shape[0])
    x = np.column_stack([ones,x])
    xTx =  x.T.dot(x)

    xTx = xTx + r*np.eye(xTx.shape[0])
    xTx_inv = np.linalg.pinv(xTx)
    w_full = xTx_inv.dot(x.T).dot(y)
    return w_full[0],w_full[1:]

# %%
x_train = prepare_x(df_train)
w0,w = train_linear_regression_reg(x_train,y_train,r=0.001)

x_val = prepare_x(df_val)
y_pred = w0 + x_val.dot(w)

rmse(y_val,y_pred)
# Out:
# np.float64(0.45651750872633906)

# %%
for r in [0.0,0.00001,0.0001,0.001,0.01,1,10]:
    X_train = prepare_x(df_train)
    w0,w =train_linear_regression_reg(x_train,y_train,r=r)

    x_val = prepare_x(df_val)
    y_pred = w0 + x_val.dot(w)
    score = rmse(y_val,y_pred)

    print(r,w0,score)
# Out:
# 0.0 6.2866488077104785 0.4565170136968238
# 1e-05 6.286638704507722 0.4565170186447376
# 0.0001 6.286228629987648 0.456517063075638
# 0.001 6.2856361559317655 0.45651750872633906
# 0.01 6.276605856602845 0.45652199012679023
# 1 5.634896630750884 0.4572204318071305
# 10 4.283980099939386 0.4701456932469492

# %%
    r = 0.001 
    X_train = prepare_x(df_train)
    w0,w =train_linear_regression_reg(x_train,y_train,r=r)

    x_val = prepare_x(df_val)
    y_pred = w0 + x_val.dot(w)
    score = rmse(y_val,y_pred)

    print(score)
# Out:
# 0.45651750872633906

# %%
df_full_train = pd.concat([df_train,df_val])

# %%
df_full_train.head()
# Out:
#          make    model  year          engine_fuel_type  engine_hp  \
# 0   chevrolet   cobalt  2008          regular_unleaded      148.0
# 1      toyota   matrix  2012          regular_unleaded      132.0
# 2      subaru  impreza  2016          regular_unleaded      148.0
# 3  volkswagen  vanagon  1991          regular_unleaded       90.0
# 4        ford    f-150  2017  flex-fuel_(unleaded/e85)      385.0
#
#    engine_cylinders transmission_type      driven_wheels  number_of_doors  \
# 0               4.0            manual  front_wheel_drive              2.0
# 1               4.0         automatic  front_wheel_drive              4.0
# 2               4.0         automatic    all_wheel_drive              4.0
# 3               4.0            manual   rear_wheel_drive              3.0
# 4               8.0         automatic   four_wheel_drive              4.0
#
#   market_category vehicle_size      vehicle_style  highway_mpg  city_mpg  \
# ...

# %%
df_full_train = df_full_train.reset_index(drop = True)

# %%
df_full_train
# Out:
#             make                    model  year             engine_fuel_type  \
# 0      chevrolet                   cobalt  2008             regular_unleaded
# 1         toyota                   matrix  2012             regular_unleaded
# 2         subaru                  impreza  2016             regular_unleaded
# 3     volkswagen                  vanagon  1991             regular_unleaded
# 4           ford                    f-150  2017     flex-fuel_(unleaded/e85)
# ...          ...                      ...   ...                          ...
# 9527       volvo                      v60  2015             regular_unleaded
# 9528    maserati  granturismo_convertible  2015  premium_unleaded_(required)
# 9529    cadillac          escalade_hybrid  2013             regular_unleaded
# 9530  mitsubishi                   lancer  2016             regular_unleaded
# 9531         kia                  sorento  2015             regular_unleaded
#
# ...

# %%
x_full_train = prepare_x(df_full_train)

# %%
x_full_train
# Out:
# array([[148.,   4.,  33., ...,   1.,   0.,   0.],
#        [132.,   4.,  32., ...,   0.,   0.,   1.],
#        [148.,   4.,  37., ...,   0.,   0.,   1.],
#        ...,
#        [332.,   8.,  23., ...,   0.,   0.,   0.],
#        [148.,   4.,  34., ...,   0.,   0.,   0.],
#        [290.,   6.,  25., ...,   0.,   0.,   0.]], shape=(9532, 41))

# %%
y_full_train = np.concatenate([y_train,y_val])

# %%
y_full_train
# Out:
# array([ 9.57574708,  9.887663  ,  9.89323518, ..., 11.21756062,
#         9.77542688, 10.1924563 ], shape=(9532,))

# %%
w0,w = train_linear_regression_reg(x_full_train,y_full_train,r=0.001)

# %%
w
# Out:
# array([ 1.52506333e-03,  1.18188700e-01, -6.66105567e-03, -5.33413912e-03,
#        -4.87603204e-05, -9.69091842e-02, -7.92621319e-01, -8.90862526e-01,
#        -6.35101248e-01, -4.14339220e-02,  1.75560742e-01, -5.78066174e-04,
#        -1.00563875e-01, -9.27549656e-02, -4.66859136e-01,  7.98659477e-02,
#        -3.16047685e-01, -5.51981656e-01, -7.89525938e-02,  1.09432840e+00,
#         9.19020856e-01,  1.14859826e+00,  2.65173413e+00,  5.08957466e-01,
#         1.62955244e+00,  1.53025650e+00,  1.61743522e+00,  1.54543460e+00,
#        -9.70559763e-02,  3.73062112e-02, -5.81767478e-02, -2.35940841e-02,
#        -1.19357139e-02,  2.18895280e+00,  2.07458290e+00,  2.05916705e+00,
#        -5.00802770e-02,  5.62184642e-02,  1.84794024e-01,  3.32646151e-01,
#        -1.58817038e-01])

# %%
    x_test = prepare_x(df_test)
    y_pred = w0 + x_test.dot(w)
    score = rmse(y_test,y_pred)

    print(score)
# Out:
# 0.4517749308187043

# %%
cars = df_test.iloc[20].to_dict()
cars
# Out:
# {'make': 'toyota',
#  'model': 'sienna',
#  'year': 2015,
#  'engine_fuel_type': 'regular_unleaded',
#  'engine_hp': 266.0,
#  'engine_cylinders': 6.0,
#  'transmission_type': 'automatic',
#  'driven_wheels': 'front_wheel_drive',
#  'number_of_doors': 4.0,
#  'market_category': nan,
#  'vehicle_size': 'large',
#  'vehicle_style': 'passenger_minivan',
#  'highway_mpg': 25,
#  'city_mpg': 18,
#  'popularity': 2031}

# %%
df_small = pd.DataFrame([cars])
df_small
# Out:
#      make   model  year  engine_fuel_type  engine_hp  engine_cylinders  \
# 0  toyota  sienna  2015  regular_unleaded      266.0               6.0
#
#   transmission_type      driven_wheels  number_of_doors  market_category  \
# 0         automatic  front_wheel_drive              4.0              NaN
#
#   vehicle_size      vehicle_style  highway_mpg  city_mpg  popularity
# 0        large  passenger_minivan           25        18        2031

# %%
x_small = prepare_x(df_small)

# %%
y_pred = w0 + x_small.dot(w)
y_pred = y_pred[0]
y_pred
# Out:
# np.float64(10.462651708402696)

# %%
np.expm1(y_pred)
# Out:
# np.float64(34983.196446554466)

# %%
y_test[20]
# Out:
# np.float64(10.463131911491967)

# %%
np.expm1(y_test[20])
