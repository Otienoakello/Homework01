# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("C:\\Users\\akelo\\Desktop\\Linear\\archive\\housing.csv")

# %%
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY

# %%
df.columns
# Out:
# Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#        'total_bedrooms', 'population', 'households', 'median_income',
#        'median_house_value', 'ocean_proximity'],
#       dtype='object')

# %%
df_columns = df.columns.str.lower().str.replace('r/s+ ','_',regex = True)

# %%
df.dtypes
# Out:
# longitude             float64
# latitude              float64
# housing_median_age    float64
# total_rooms           float64
# total_bedrooms        float64
# population            float64
# households            float64
# median_income         float64
# median_house_value    float64
# ocean_proximity        object
# dtype: object

# %%
df_columns = df.columns.str.replace('median_house_value','house_value')

# %%
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY

# %%
df_columns
# Out:
# Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#        'total_bedrooms', 'population', 'households', 'median_income',
#        'house_value', 'ocean_proximity'],
#       dtype='object')

# %%
df.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  20640.000000  20640.000000        20640.000000  20640.000000
# mean    -119.569704     35.631861           28.639486   2635.763081
# std        2.003532      2.135952           12.585558   2181.615252
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.800000     33.930000           18.000000   1447.750000
# 50%     -118.490000     34.260000           29.000000   2127.000000
# 75%     -118.010000     37.710000           37.000000   3148.000000
# max     -114.310000     41.950000           52.000000  39320.000000
#
#        total_bedrooms    population    households  median_income  \
# count    20433.000000  20640.000000  20640.000000   20640.000000
# mean       537.870553   1425.476744    499.539680       3.870671
# std        421.385070   1132.462122    382.329753       1.899822
# min          1.000000      3.000000      1.000000       0.499900
# ...

# %%
df.isnull()
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0          False     False               False        False           False
# 1          False     False               False        False           False
# 2          False     False               False        False           False
# 3          False     False               False        False           False
# 4          False     False               False        False           False
# ...          ...       ...                 ...          ...             ...
# 20635      False     False               False        False           False
# 20636      False     False               False        False           False
# 20637      False     False               False        False           False
# 20638      False     False               False        False           False
# 20639      False     False               False        False           False
#
# ...

# %%
df.isnull().sum()
# Out:
# longitude               0
# latitude                0
# housing_median_age      0
# total_rooms             0
# total_bedrooms        207
# population              0
# households              0
# median_income           0
# median_house_value      0
# ocean_proximity         0
# dtype: int64

# %%
df.count()
# Out:
# longitude             20640
# latitude              20640
# housing_median_age    20640
# total_rooms           20640
# total_bedrooms        20433
# population            20640
# households            20640
# median_income         20640
# median_house_value    20640
# ocean_proximity       20640
# dtype: int64

# %%
df.columns =(
    df.columns.str.strip().str.replace('r/+s', '_',regex =True).str.lower().str.replace('median_house_value','house_value')
)

# %%
df.columns
# Out:
# Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#        'total_bedrooms', 'population', 'households', 'median_income',
#        'house_value', 'ocean_proximity'],
#       dtype='object')

# %%
df.dtypes
# Out:
# longitude             float64
# latitude              float64
# housing_median_age    float64
# total_rooms           float64
# total_bedrooms        float64
# population            float64
# households            float64
# median_income         float64
# house_value           float64
# ocean_proximity        object
# dtype: object

# %%
df.dtypes == object
# Out:
# longitude             False
# latitude              False
# housing_median_age    False
# total_rooms           False
# total_bedrooms        False
# population            False
# households            False
# median_income         False
# house_value           False
# ocean_proximity        True
# dtype: bool

# %%
df.dtypes[df.dtypes == 'object']
# Out:
# ocean_proximity    object
# dtype: object

# %%
Strings = list(df.dtypes[df.dtypes == 'object'].index)
Strings
# Out:
# ['ocean_proximity']

# %%
for col in Strings:
    df[col] = df[col].str.lower().str.replace('r/s+','_')

# %%
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  house_value ocean_proximity
# 0       322.0       126.0         8.3252     452600.0        near bay
# 1      2401.0      1138.0         8.3014     358500.0        near bay
# 2       496.0       177.0         7.2574     352100.0        near bay
# 3       558.0       219.0         5.6431     341300.0        near bay
# 4       565.0       259.0         3.8462     342200.0        near bay

# %%
for col in df.columns:
    print(col)
    print(df[col].unique()[:5])
    print(df[col].nunique())
    print()
# Out:
# longitude
# [-122.23 -122.22 -122.24 -122.25 -122.26]
# 844
#
# latitude
# [37.88 37.86 37.85 37.84 37.83]
# 862
#
# housing_median_age
# [41. 21. 52. 42. 50.]
# 52
#
# total_rooms
# [ 880. 7099. 1467. 1274. 1627.]
# 5926
#
# total_bedrooms
# [ 129. 1106.  190.  235.  280.]
# 1923
#
# population
# [ 322. 2401.  496.  558.  565.]
# 3888
#
# households
# [ 126. 1138.  177.  219.  259.]
# 1815
#
# median_income
# [8.3252 8.3014 7.2574 5.6431 3.8462]
# 12928
#
# house_value
# [452600. 358500. 352100. 341300. 342200.]
# 3842
#
# ocean_proximity
# ['near bay' '<1h ocean' 'inland' 'near ocean' 'island']
# 5

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# %matplotlib inline

# %%
sns.histplot(df.house_value,bins = 50)
# Out:
# <Axes: xlabel='house_value', ylabel='Count'>

# %%
df.isnull().sum()
# Out:
# longitude               0
# latitude                0
# housing_median_age      0
# total_rooms             0
# total_bedrooms        207
# population              0
# households              0
# median_income           0
# house_value             0
# ocean_proximity         0
# dtype: int64

# %%
print(col)
print(df[col].head())
print()
# Out:
# ocean_proximity
# 0    near bay
# 1    near bay
# 2    near bay
# 3    near bay
# 4    near bay
# Name: ocean_proximity, dtype: object

# %%
n = len(df)

# %%
n_train = int(n*0.6)
n_val = int(n*0.2)
n_test = n-(n_train+n_val)

# %%
n_train,n_val,n_test
# Out:
# (12384, 4128, 4128)

# %%
df_train =df.iloc[:n_train]
df_val = df.iloc[n_train:n_train + n_val]
df_test = df.iloc[n_train + n_val:]

# %%
df_train
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 12379    -116.46     33.78                33.0       2565.0           745.0
# 12380    -116.47     33.77                26.0       4300.0           767.0
# 12381    -116.47     33.78                27.0       1781.0           441.0
# 12382    -116.38     33.73                10.0      11836.0          2405.0
# 12383    -116.37     33.72                17.0       8626.0          1859.0
#
# ...

# %%
df_val
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 16512    -121.22     37.72                34.0       2123.0           387.0
# 16513    -121.22     37.81                17.0       2879.0           542.0
# 16514    -121.22     37.80                28.0       2608.0           576.0
# 16515    -121.22     37.80                37.0       1038.0           222.0
# 16516    -121.21     37.81                18.0       2404.0           498.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %%
total = n_train+n_val+n_test

# %%
total
# Out:
# 20640

# %%
idx =np.arange(n)
np.random.shuffle(idx)
idx
# Out:
# array([20261, 17266, 10230, ...,  5353, 19575, 15570], shape=(20640,))

# %%
df_train =df.iloc[idx[:n_train]]
df_val = df.iloc[idx[n_train:n_train + n_val]]
df_test = df.iloc[idx[n_train + n_val:]]

# %%
df_train
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 20261    -119.18     34.21                29.0       4039.0           680.0
# 17266    -119.71     34.36                34.0       1706.0           276.0
# 10230    -117.93     33.86                17.0       1627.0           398.0
# 6238     -117.97     34.05                33.0       1452.0           268.0
# 17623    -121.94     37.26                21.0       3843.0           716.0
# ...          ...       ...                 ...          ...             ...
# 11045    -117.83     33.81                24.0       3550.0           895.0
# 10886    -117.91     33.71                16.0       3113.0           783.0
# 5617     -118.26     33.79                42.0       1162.0           264.0
# 6755     -118.10     34.11                49.0       3367.0           523.0
# 5357     -118.39     34.05                42.0       3105.0           559.0
#
# ...

# %%
df_test
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 221      -122.21     37.80                39.0       2018.0           447.0
# 20205    -119.20     34.28                22.0       2362.0           601.0
# 2420     -119.44     36.58                37.0       1054.0             NaN
# 1354     -121.94     38.02                29.0       5765.0          1170.0
# 10738    -117.91     33.60                37.0       2088.0           510.0
# ...          ...       ...                 ...          ...             ...
# 7431     -118.20     33.94                42.0        618.0           163.0
# 15993    -122.47     37.76                34.0       2807.0           487.0
# 5353     -118.40     34.03                36.0       1831.0           296.0
# 19575    -120.54     37.68                18.0        335.0            76.0
# 15570    -116.89     32.99                14.0       2816.0           501.0
#
# ...

# %%
df_val
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 2507     -120.51     36.86                21.0       1779.0           399.0
# 16945    -122.32     37.55                44.0       2151.0           411.0
# 8475     -118.32     33.91                34.0       1068.0           198.0
# 5771     -118.27     34.15                22.0       2265.0           637.0
# 10642    -117.80     33.55                38.0       1757.0           464.0
# ...          ...       ...                 ...          ...             ...
# 4924     -118.24     34.00                23.0        588.0           157.0
# 9401     -122.56     37.92                37.0       1926.0           290.0
# 13359    -117.66     34.02                12.0       5616.0           871.0
# 18901    -122.26     38.11                52.0       1560.0           353.0
# 5623     -118.26     33.77                36.0        886.0           253.0
#
# ...

# %%
np.random.seed(2)
np.random.shuffle(idx)

# %%
df_test
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 221      -122.21     37.80                39.0       2018.0           447.0
# 20205    -119.20     34.28                22.0       2362.0           601.0
# 2420     -119.44     36.58                37.0       1054.0             NaN
# 1354     -121.94     38.02                29.0       5765.0          1170.0
# 10738    -117.91     33.60                37.0       2088.0           510.0
# ...          ...       ...                 ...          ...             ...
# 7431     -118.20     33.94                42.0        618.0           163.0
# 15993    -122.47     37.76                34.0       2807.0           487.0
# 5353     -118.40     34.03                36.0       1831.0           296.0
# 19575    -120.54     37.68                18.0        335.0            76.0
# 15570    -116.89     32.99                14.0       2816.0           501.0
#
# ...

# %%
df_test
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 221      -122.21     37.80                39.0       2018.0           447.0
# 20205    -119.20     34.28                22.0       2362.0           601.0
# 2420     -119.44     36.58                37.0       1054.0             NaN
# 1354     -121.94     38.02                29.0       5765.0          1170.0
# 10738    -117.91     33.60                37.0       2088.0           510.0
# ...          ...       ...                 ...          ...             ...
# 7431     -118.20     33.94                42.0        618.0           163.0
# 15993    -122.47     37.76                34.0       2807.0           487.0
# 5353     -118.40     34.03                36.0       1831.0           296.0
# 19575    -120.54     37.68                18.0        335.0            76.0
# 15570    -116.89     32.99                14.0       2816.0           501.0
#
# ...

# %%
len(df_train),len(df_val),len(df_test)
# Out:
# (12384, 4128, 4128)

# %%
df_train.reset_index(drop = True)
df_val.reset_index(drop = True)
df_test.reset_index(drop =True)
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0       -122.21     37.80                39.0       2018.0           447.0
# 1       -119.20     34.28                22.0       2362.0           601.0
# 2       -119.44     36.58                37.0       1054.0             NaN
# 3       -121.94     38.02                29.0       5765.0          1170.0
# 4       -117.91     33.60                37.0       2088.0           510.0
# ...         ...       ...                 ...          ...             ...
# 4123    -118.20     33.94                42.0        618.0           163.0
# 4124    -122.47     37.76                34.0       2807.0           487.0
# 4125    -118.40     34.03                36.0       1831.0           296.0
# 4126    -120.54     37.68                18.0        335.0            76.0
# 4127    -116.89     32.99                14.0       2816.0           501.0
#
# ...

# %%
df_train = df_train.reset_index(drop = True)
df_val = df_val.reset_index(drop = True)
df_test = df_test.reset_index(drop =True)

# %%
df_train
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -119.18     34.21                29.0       4039.0           680.0
# 1        -119.71     34.36                34.0       1706.0           276.0
# 2        -117.93     33.86                17.0       1627.0           398.0
# 3        -117.97     34.05                33.0       1452.0           268.0
# 4        -121.94     37.26                21.0       3843.0           716.0
# ...          ...       ...                 ...          ...             ...
# 12379    -117.83     33.81                24.0       3550.0           895.0
# 12380    -117.91     33.71                16.0       3113.0           783.0
# 12381    -118.26     33.79                42.0       1162.0           264.0
# 12382    -118.10     34.11                49.0       3367.0           523.0
# 12383    -118.39     34.05                42.0       3105.0           559.0
#
# ...

# %%
df_val
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0       -120.51     36.86                21.0       1779.0           399.0
# 1       -122.32     37.55                44.0       2151.0           411.0
# 2       -118.32     33.91                34.0       1068.0           198.0
# 3       -118.27     34.15                22.0       2265.0           637.0
# 4       -117.80     33.55                38.0       1757.0           464.0
# ...         ...       ...                 ...          ...             ...
# 4123    -118.24     34.00                23.0        588.0           157.0
# 4124    -122.56     37.92                37.0       1926.0           290.0
# 4125    -117.66     34.02                12.0       5616.0           871.0
# 4126    -122.26     38.11                52.0       1560.0           353.0
# 4127    -118.26     33.77                36.0        886.0           253.0
#
# ...

# %%
df_test
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0       -122.21     37.80                39.0       2018.0           447.0
# 1       -119.20     34.28                22.0       2362.0           601.0
# 2       -119.44     36.58                37.0       1054.0             NaN
# 3       -121.94     38.02                29.0       5765.0          1170.0
# 4       -117.91     33.60                37.0       2088.0           510.0
# ...         ...       ...                 ...          ...             ...
# 4123    -118.20     33.94                42.0        618.0           163.0
# 4124    -122.47     37.76                34.0       2807.0           487.0
# 4125    -118.40     34.03                36.0       1831.0           296.0
# 4126    -120.54     37.68                18.0        335.0            76.0
# 4127    -116.89     32.99                14.0       2816.0           501.0
#
# ...

# %%
del df_train['house_value']
del df_test['house_value']
del df_val['house_value']

# %%
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  house_value ocean_proximity
# 0       322.0       126.0         8.3252     452600.0        near bay
# 1      2401.0      1138.0         8.3014     358500.0        near bay
# 2       496.0       177.0         7.2574     352100.0        near bay
# 3       558.0       219.0         5.6431     341300.0        near bay
# 4       565.0       259.0         3.8462     342200.0        near bay

# %%
df_train
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -119.18     34.21                29.0       4039.0           680.0
# 1        -119.71     34.36                34.0       1706.0           276.0
# 2        -117.93     33.86                17.0       1627.0           398.0
# 3        -117.97     34.05                33.0       1452.0           268.0
# 4        -121.94     37.26                21.0       3843.0           716.0
# ...          ...       ...                 ...          ...             ...
# 12379    -117.83     33.81                24.0       3550.0           895.0
# 12380    -117.91     33.71                16.0       3113.0           783.0
# 12381    -118.26     33.79                42.0       1162.0           264.0
# 12382    -118.10     34.11                49.0       3367.0           523.0
# 12383    -118.39     34.05                42.0       3105.0           559.0
#
# ...

# %%
house_price = np.log1p(df.house_value)
house_price
# Out:
# 0        13.022766
# 1        12.789687
# 2        12.771673
# 3        12.740520
# 4        12.743154
#            ...
# 20635    11.265758
# 20636    11.252872
# 20637    11.432810
# 20638    11.346883
# 20639    11.400887
# Name: house_value, Length: 20640, dtype: float64

# %%
sns.histplot(house_price,bins = 50)
# Out:
# <Axes: xlabel='house_value', ylabel='Count'>

# %%
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  house_value ocean_proximity
# 0       322.0       126.0         8.3252     452600.0        near bay
# 1      2401.0      1138.0         8.3014     358500.0        near bay
# 2       496.0       177.0         7.2574     352100.0        near bay
# 3       558.0       219.0         5.6431     341300.0        near bay
# 4       565.0       259.0         3.8462     342200.0        near bay

# %%
df_train.iloc[10]
# Out:
# longitude               -118.37
# latitude                  34.23
# housing_median_age         32.0
# total_rooms              1444.0
# total_bedrooms            317.0
# population               1177.0
# households                311.0
# median_income               3.6
# ocean_proximity       <1h ocean
# Name: 10, dtype: object

# %%
xi = [32,1444.0,3.6]

# %%
def linear_regression(xi):
    n = len (xi)
    pred = w0

    for j in range(n):
      pred = pred + w[j]*xi[j]
    return pred

# %%
w0 = -3.55276
w = [0.04,0.009,0.002]

# %%
linear_regression(xi)
# Out:
# 10.730439999999998

# %%
np.expm1(linear_regression(xi))
# Out:
# np.float64(45725.807395949094)
